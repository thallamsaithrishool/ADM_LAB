# %% [markdown]
# <a href="https://colab.research.google.com/github/thallamsaithrishool/ADM_LAB/blob/main/ADM_LAB_08_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
data=pd.read_csv('/content/DATASET-SALES.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         3 non-null      float64
#  1   RADIO      3 non-null      float64
#  2   NEWSPAPER  3 non-null      float64
#  3   SALES      3 non-null      float64
# dtypes: float64(4)
# memory usage: 228.0 bytes

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#       TV  RADIO  NEWSPAPER  SALES
# 0  230.0   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3

# %%
X=df[['TV','RADIO','NEWSPAPER']]
y=df[['SALES']]

# %%
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X)

# %%
print(f"coefficients:{model.coef_}")
print(f"intercept:{model.intercept_}")
# Out:
# coefficients:[[0.06026421 0.0027217  0.02178718]]
# intercept:[6.62867799]

# %%
mse=mean_squared_error(y,y_pred)
r2=r2_score(y,y_pred)

# %%
print(f"mean squared error:{mse}")
print(f"R_squared:{r2}")
# Out:
# mean squared error:9.466330862652142e-30
# R_squared:1.0

# %%
plt.figure(figsize=(6,4))
plt.scatter(y,y_pred)
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual Sales vs Predicted Sales')
plt.show()
